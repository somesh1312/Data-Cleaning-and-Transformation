# %% [markdown]
# # Importing the libraries and loading the uncleaned Datasets

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('Uncleaned_DS_jobs.csv')

# %% [markdown]
# # Data Exploration

# %%
#Displays first 5 columns and rows
df.head()
# Out:
#    index          Job Title               Salary Estimate  \
# 0      0  Sr Data Scientist  $137K-$171K (Glassdoor est.)
# 1      1     Data Scientist  $137K-$171K (Glassdoor est.)
# 2      2     Data Scientist  $137K-$171K (Glassdoor est.)
# 3      3     Data Scientist  $137K-$171K (Glassdoor est.)
# 4      4     Data Scientist  $137K-$171K (Glassdoor est.)
#
#                                      Job Description  Rating  \
# 0  Description\n\nThe Senior Data Scientist is re...     3.1
# 1  Secure our Nation, Ignite your Future\n\nJoin ...     4.2
# 2  Overview\n\n\nAnalysis Group is one of the lar...     3.8
# 3  JOB DESCRIPTION:\n\nDo you have a passion for ...     3.5
# 4  Data Scientist\nAffinity Solutions / Marketing...     2.9
#
#               Company Name       Location            Headquarters  \
# 0         Healthfirst\n3.1   New York, NY            New York, NY
# 1             ManTech\n4.2  Chantilly, VA             Herndon, VA
# ...

# %%
#Shows the number of rows and columns in the dataset
df.shape
# Out:
# (672, 15)

# %%
#Displays the detailed information of all the columns
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 672 entries, 0 to 671
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   index              672 non-null    int64
#  1   Job Title          672 non-null    object
#  2   Salary Estimate    672 non-null    object
#  3   Job Description    672 non-null    object
#  4   Rating             672 non-null    float64
#  5   Company Name       672 non-null    object
#  6   Location           672 non-null    object
#  7   Headquarters       672 non-null    object
#  8   Size               672 non-null    object
#  9   Founded            672 non-null    int64
#  10  Type of ownership  672 non-null    object
#  11  Industry           672 non-null    object
#  12  Sector             672 non-null    object
#  13  Revenue            672 non-null    object
#  14  Competitors        672 non-null    object
# dtypes: float64(1), int64(2), object(12)
# ...

# %%
#This set of code displays all the rows and columns in the dataset.
pd.set_option('display.max_columns',None)
pd.set_option('display.max_rows',None)

# %%
#Checks for the null value in the dataset.
df.isnull().sum()
# Out:
# index                0
# Job Title            0
# Salary Estimate      0
# Job Description      0
# Rating               0
# Company Name         0
# Location             0
# Headquarters         0
# Size                 0
# Founded              0
# Type of ownership    0
# Industry             0
# Sector               0
# Revenue              0
# Competitors          0
# dtype: int64

# %%
#dropping the index columns to find the duplicates as Python understands that all the columns are unique
df.drop('index',axis=1,inplace=True)

# %%
#checking whether the index column is dropped
df.head()
# Out:
#            Job Title               Salary Estimate  \
# 0  Sr Data Scientist  $137K-$171K (Glassdoor est.)
# 1     Data Scientist  $137K-$171K (Glassdoor est.)
# 2     Data Scientist  $137K-$171K (Glassdoor est.)
# 3     Data Scientist  $137K-$171K (Glassdoor est.)
# 4     Data Scientist  $137K-$171K (Glassdoor est.)
#
#                                      Job Description  Rating  \
# 0  Description\n\nThe Senior Data Scientist is re...     3.1
# 1  Secure our Nation, Ignite your Future\n\nJoin ...     4.2
# 2  Overview\n\n\nAnalysis Group is one of the lar...     3.8
# 3  JOB DESCRIPTION:\n\nDo you have a passion for ...     3.5
# 4  Data Scientist\nAffinity Solutions / Marketing...     2.9
#
#               Company Name       Location            Headquarters  \
# 0         Healthfirst\n3.1   New York, NY            New York, NY
# 1             ManTech\n4.2  Chantilly, VA             Herndon, VA
# 2      Analysis Group\n3.8     Boston, MA              Boston, MA
# ...

# %%
#Shows the number of duplicate rows and columns
print(df[df.duplicated()].shape)
# Out:
# (13, 14)

# %%
#Displays all the duplicate rows and columns
df[df.duplicated()]
# Out:
#                      Job Title               Salary Estimate  \
# 135  Machine Learning Engineer   $90K-$109K (Glassdoor est.)
# 136       Senior Data Engineer   $90K-$109K (Glassdoor est.)
# 358             Data Scientist  $122K-$146K (Glassdoor est.)
# 359             Data Scientist  $122K-$146K (Glassdoor est.)
# 360             Data Scientist  $122K-$146K (Glassdoor est.)
# 361             Data Scientist  $122K-$146K (Glassdoor est.)
# 362             Data Scientist  $122K-$146K (Glassdoor est.)
# 389             Data Scientist  $110K-$163K (Glassdoor est.)
# 496             Data Scientist   $95K-$119K (Glassdoor est.)
# 497             Data Scientist   $95K-$119K (Glassdoor est.)
# 498             Data Scientist   $95K-$119K (Glassdoor est.)
# 499             Data Scientist   $95K-$119K (Glassdoor est.)
# 500             Data Scientist   $95K-$119K (Glassdoor est.)
#
#                                        Job Description  Rating  \
# ...

# %%
#drop all the duplicates values
df.drop_duplicates(inplace=True)

# %%
#checking the rows and columns after removing the duplicates
df.shape
# Out:
# (659, 14)

# %%
#reset the index,post removal of duplicates
df.reset_index(inplace=True)

# %%
df.head()
# Out:
#    index          Job Title               Salary Estimate  \
# 0      0  Sr Data Scientist  $137K-$171K (Glassdoor est.)
# 1      1     Data Scientist  $137K-$171K (Glassdoor est.)
# 2      2     Data Scientist  $137K-$171K (Glassdoor est.)
# 3      3     Data Scientist  $137K-$171K (Glassdoor est.)
# 4      4     Data Scientist  $137K-$171K (Glassdoor est.)
#
#                                      Job Description  Rating  \
# 0  Description\n\nThe Senior Data Scientist is re...     3.1
# 1  Secure our Nation, Ignite your Future\n\nJoin ...     4.2
# 2  Overview\n\n\nAnalysis Group is one of the lar...     3.8
# 3  JOB DESCRIPTION:\n\nDo you have a passion for ...     3.5
# 4  Data Scientist\nAffinity Solutions / Marketing...     2.9
#
#               Company Name       Location            Headquarters  \
# 0         Healthfirst\n3.1   New York, NY            New York, NY
# 1             ManTech\n4.2  Chantilly, VA             Herndon, VA
# ...

# %% [markdown]
# # Removing the integer values in company column

# %%
df['Company Name']=df['Company Name'].apply(lambda x:x.split("\n")[0])

# %%
#Verifying the above code
df.head()
# Out:
#    index          Job Title               Salary Estimate  \
# 0      0  Sr Data Scientist  $137K-$171K (Glassdoor est.)
# 1      1     Data Scientist  $137K-$171K (Glassdoor est.)
# 2      2     Data Scientist  $137K-$171K (Glassdoor est.)
# 3      3     Data Scientist  $137K-$171K (Glassdoor est.)
# 4      4     Data Scientist  $137K-$171K (Glassdoor est.)
#
#                                      Job Description  Rating  \
# 0  Description\n\nThe Senior Data Scientist is re...     3.1
# 1  Secure our Nation, Ignite your Future\n\nJoin ...     4.2
# 2  Overview\n\n\nAnalysis Group is one of the lar...     3.8
# 3  JOB DESCRIPTION:\n\nDo you have a passion for ...     3.5
# 4  Data Scientist\nAffinity Solutions / Marketing...     2.9
#
#          Company Name       Location            Headquarters  \
# 0         Healthfirst   New York, NY            New York, NY
# 1             ManTech  Chantilly, VA             Herndon, VA
# ...

# %% [markdown]
# # Changing the salary estimate column from string to integer

# %% [markdown]
# 1. Removing all the string values in salary estimate column
# 2. Creating new columns(max_salary,min_salary,abg_salary)
# 3. Remove extra symbol and character in the respective column

# %%
#Counting the number of values in the salary estimate column
df['Salary Estimate'].value_counts()
# Out:
# Salary Estimate
# $75K-$131K (Glassdoor est.)     32
# $79K-$131K (Glassdoor est.)     32
# $99K-$132K (Glassdoor est.)     32
# $137K-$171K (Glassdoor est.)    30
# $90K-$109K (Glassdoor est.)     28
# $56K-$97K (Glassdoor est.)      22
# $79K-$106K (Glassdoor est.)     22
# $90K-$124K (Glassdoor est.)     22
# $92K-$155K (Glassdoor est.)     21
# $138K-$158K (Glassdoor est.)    21
# $128K-$201K (Glassdoor est.)    21
# $212K-$331K (Glassdoor est.)    21
# $69K-$116K (Glassdoor est.)     21
# $124K-$198K (Glassdoor est.)    21
# $112K-$116K (Glassdoor est.)    21
# $91K-$150K (Glassdoor est.)     21
# $101K-$165K (Glassdoor est.)    21
# $110K-$163K (Glassdoor est.)    20
# $79K-$147K (Glassdoor est.)     20
# $145K-$225K(Employer est.)      20
# $31K-$56K (Glassdoor est.)      20
# $141K-$225K (Glassdoor est.)    20
# $66K-$112K (Glassdoor est.)     20
# $80K-$132K (Glassdoor est.)     20
# $87K-$141K (Glassdoor est.)     20
# $105K-$167K (Glassdoor est.)    20
# ...

# %%
#importing Regular expression to replace specific type of pattern in respective columns
import re
df['min_salary'] = df['Salary Estimate'].apply(lambda x: int(re.findall(r'\d+', x.split('-')[0])[0]))
df['max_salary'] = df['Salary Estimate'].apply(lambda x: int(re.findall(r'\d+', x.split('-')[1])[0]))
df['avg_salary'] = (df['min_salary'] + df['max_salary']) / 2

# %%
df['min_salary'] = df['min_salary'] * 1000
df['max_salary'] = df['max_salary'] * 1000
df['avg_salary'] = df['avg_salary'] * 1000

# %%
df.head()
# Out:
#    index          Job Title               Salary Estimate  \
# 0      0  Sr Data Scientist  $137K-$171K (Glassdoor est.)
# 1      1     Data Scientist  $137K-$171K (Glassdoor est.)
# 2      2     Data Scientist  $137K-$171K (Glassdoor est.)
# 3      3     Data Scientist  $137K-$171K (Glassdoor est.)
# 4      4     Data Scientist  $137K-$171K (Glassdoor est.)
#
#                                      Job Description  Rating  \
# 0  Description\n\nThe Senior Data Scientist is re...     3.1
# 1  Secure our Nation, Ignite your Future\n\nJoin ...     4.2
# 2  Overview\n\n\nAnalysis Group is one of the lar...     3.8
# 3  JOB DESCRIPTION:\n\nDo you have a passion for ...     3.5
# 4  Data Scientist\nAffinity Solutions / Marketing...     2.9
#
#          Company Name       Location            Headquarters  \
# 0         Healthfirst   New York, NY            New York, NY
# 1             ManTech  Chantilly, VA             Herndon, VA
# ...

# %%
df['min_salary'] = df['min_salary'] / 1000
df['max_salary'] = df['max_salary'] / 1000

# %%
df['min_salary'] = df['min_salary'].astype(int)

# %%
df['max_salary'] = df['max_salary'].astype(int)
df['avg_salary'] = df['avg_salary'].astype(int)

# %%
#Changing the Salary estimate column using min,max,avg columns.
for i in range(len(df)):
    df.loc[i, "Salary Estimate"] = str(df.loc[i, "min_salary"]) + "-" + str(df.loc[i, "max_salary"])

# %%
df.head()
# Out:
#    level_0  index          Job Title Salary Estimate  \
# 0        0      0  Sr Data Scientist   137000-171000
# 1        1      1     Data Scientist   137000-171000
# 2        2      2     Data Scientist   137000-171000
# 3        3      3     Data Scientist   137000-171000
# 4        4      4     Data Scientist   137000-171000
#
#                                      Job Description  Rating  \
# 0  Description\n\nThe Senior Data Scientist is re...     3.1
# 1  Secure our Nation, Ignite your Future\n\nJoin ...     4.2
# 2  Overview\n\n\nAnalysis Group is one of the lar...     3.8
# 3  JOB DESCRIPTION:\n\nDo you have a passion for ...     3.5
# 4  Data Scientist\nAffinity Solutions / Marketing...     2.9
#
#          Company Name       Location            Headquarters  \
# 0         Healthfirst   New York, NY            New York, NY
# 1             ManTech  Chantilly, VA             Herndon, VA
# 2      Analysis Group     Boston, MA              Boston, MA
# ...

# %% [markdown]
# # Exctract Data Job Description
# Create New Columns Based on Skill required for Job (Python,Excel,Sql,Tableau,Sparx,mechine learing,Aws) If Job description Contain Those skill in column print '1' otherwise '0' will print

# %%
df['Job Description'][0].split("\n\n")
# Out:
# ['Description',
#  'The Senior Data Scientist is responsible for defining, building, and improving statistical models to improve business processes and outcomes in one or more healthcare domains such as Clinical, Enrollment, Claims, and Finance. As part of the broader analytics team, Data Scientist will gather and analyze data to solve and address complex business problems and evaluate scenarios to make predictions on future outcomes and work with the business to communicate and support decision-making. This position requires strong analytical skills and experience in analytic methods including multivariate regressions, hierarchical linear models, regression trees, clustering methods and other complex statistical techniques.',
#  'Duties & Responsibilities:',
# ...

# %%
df['python']=df['Job Description'].apply(lambda x: 1 if "python" in x.lower() else 0)
df['excel']=df['Job Description'].apply(lambda x: 1 if "excel" in x.lower() else 0)
df['Sql']=df['Job Description'].apply(lambda x: 1 if "sql" in x.lower() else 0)
df['tableau']=df['Job Description'].apply(lambda x: 1 if "tableau" in x.lower() else 0)
df['Sparx']=df['Job Description'].apply(lambda x: 1 if "Sparx" in x.lower() else 0)
df['machine learning']=df['Job Description'].apply(lambda x: 1 if "machine learning" in x.lower() else 0)
df['aws']=df['Job Description'].apply(lambda x: 1 if "aws" in x.lower() else 0)

# %%
df.head()
# Out:
#    index          Job Title    Salary Estimate  \
# 0      0  Sr Data Scientist  137000.0-171000.0
# 1      1     Data Scientist  137000.0-171000.0
# 2      2     Data Scientist  137000.0-171000.0
# 3      3     Data Scientist  137000.0-171000.0
# 4      4     Data Scientist  137000.0-171000.0
#
#                                      Job Description  Rating  \
# 0  Description\n\nThe Senior Data Scientist is re...     3.1
# 1  Secure our Nation, Ignite your Future\n\nJoin ...     4.2
# 2  Overview\n\n\nAnalysis Group is one of the lar...     3.8
# 3  JOB DESCRIPTION:\n\nDo you have a passion for ...     3.5
# 4  Data Scientist\nAffinity Solutions / Marketing...     2.9
#
#          Company Name       Location            Headquarters  \
# 0         Healthfirst   New York, NY            New York, NY
# 1             ManTech  Chantilly, VA             Herndon, VA
# 2      Analysis Group     Boston, MA              Boston, MA
# 3             INFICON     Newton, MA  Bad Ragaz, Switzerland
# ...

# %% [markdown]
# # Create New Column State Using ['Location'] column

# %%
df['State']= df['Location'].apply(lambda x:x.split(",")[-1].strip())
df['State'].replace(['United States','New Jersey','California','Texas ','Remote','Utah'],["US","NJ","CA","Tx",np.nan,np.nan],inplace=True)
df.dropna(axis=0,inplace= True)
df.reset_index(inplace= True)

# %%
df.head()
# Out:
#    level_0  index          Job Title    Salary Estimate  \
# 0        0      0  Sr Data Scientist  137000.0-171000.0
# 1        1      1     Data Scientist  137000.0-171000.0
# 2        2      2     Data Scientist  137000.0-171000.0
# 3        3      3     Data Scientist  137000.0-171000.0
# 4        4      4     Data Scientist  137000.0-171000.0
#
#                                      Job Description  Rating  \
# 0  Description\n\nThe Senior Data Scientist is re...     3.1
# 1  Secure our Nation, Ignite your Future\n\nJoin ...     4.2
# 2  Overview\n\n\nAnalysis Group is one of the lar...     3.8
# 3  JOB DESCRIPTION:\n\nDo you have a passion for ...     3.5
# 4  Data Scientist\nAffinity Solutions / Marketing...     2.9
#
#          Company Name       Location            Headquarters  \
# 0         Healthfirst   New York, NY            New York, NY
# 1             ManTech  Chantilly, VA             Herndon, VA
# 2      Analysis Group     Boston, MA              Boston, MA
# ...

# %%
df['Job Title'].value_counts()
# Out:
# Job Title
# Data Scientist                                                                                      326
# Data Engineer                                                                                        26
# Senior Data Scientist                                                                                19
# Machine Learning Engineer                                                                            14
# Data Analyst                                                                                         12
# Senior Data Analyst                                                                                   6
# Senior Data Engineer                                                                                  4
# ENGINEER - COMPUTER SCIENTIST - RESEARCH COMPUTER SCIENTIST - SIGNAL PROCESSING - SAN ANTONIO OR      4
# Data Science Software Engineer                                                                        4
# ...

# %%
def employeetype(job_title):
    job_title=job_title.lower()
    emp=['sr','senior','lead','principal','vp','vice president','director']
    for i in emp:
        if i in job_title:
            return "Senior employee"
        else:
            return "junior employee"
    return NaN

# %%
df['Employee experience ']= df['Job Title'].apply(employeetype)

# %%
df.head()
# Out:
#    level_0  index          Job Title    Salary Estimate  \
# 0        0      0  Sr Data Scientist  137000.0-171000.0
# 1        1      1     Data Scientist  137000.0-171000.0
# 2        2      2     Data Scientist  137000.0-171000.0
# 3        3      3     Data Scientist  137000.0-171000.0
# 4        4      4     Data Scientist  137000.0-171000.0
#
#                                      Job Description  Rating  \
# 0  Description\n\nThe Senior Data Scientist is re...     3.1
# 1  Secure our Nation, Ignite your Future\n\nJoin ...     4.2
# 2  Overview\n\n\nAnalysis Group is one of the lar...     3.8
# 3  JOB DESCRIPTION:\n\nDo you have a passion for ...     3.5
# 4  Data Scientist\nAffinity Solutions / Marketing...     2.9
#
#          Company Name       Location            Headquarters  \
# 0         Healthfirst   New York, NY            New York, NY
# 1             ManTech  Chantilly, VA             Herndon, VA
# 2      Analysis Group     Boston, MA              Boston, MA
# ...

# %%
df.nunique()
# Out:
# level_0                 652
# index                   652
# Job Title               168
# Salary Estimate          30
# Job Description         484
# Rating                   32
# Company Name            428
# Location                205
# Headquarters            228
# Size                      9
# Founded                 103
# Type of ownership        13
# Industry                 58
# Sector                   23
# Revenue                  14
# Competitors             108
# min_salary               26
# max_salary               26
# avg_salary               26
# python                    2
# excel                     2
# Sql                       2
# tableau                   2
# Sparx                     1
# machine learning          2
# aws                       2
# State                    40
# Employee experience       2
# dtype: int64

# %%
df.to_csv('Data_science Job',index=False)
